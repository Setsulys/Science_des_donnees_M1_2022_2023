# %% [markdown]
# # TP 5 : Réseaux de Neurones en tensorflow

# %% [markdown]
# **Avant de commencer :** Merci de bien lire le préambule et l'énoncé de ce TP. Ça vous évitera de perdre beaucoup de temps ensuite.

# %% [markdown]
# **Rendu :** Ce TP doit être déposé sur elearning avant le 23 novembre 2022, 23h59. Le rendu doit contenir uniquement le fichier `.ipynb`. Le notebook doit être propre, le plus illustré et le plus commenté possible.

# %% [markdown]
# **Librairies :** Ce TP repose sur les librairies standard suivantes :
# - Version numpy : 1.23.1
# - Version matplotlib : 3.5.2
# - Version tensorflow : 2.8.2
#
# Pour vérifier qu'elles sont bien installées dans votre environnement de travail, lancez la cellule suivante. Elle ne doit pas renvoyer d'erreur (un `Warning` n'est en général pas trop embêtant).
#
# Pour les numéros _exacts_ de version, ce n'est pas très grave s'il y a une petite différence (par exemple `numpy 1.22` au lieu de `1.23`), mais si vous avez une trop grosse différence (par exemple `sklearn 0.23` au lieu de `sklearn 1.1`), mettez à jour votre librairie.
#
# S'il vous manque une librairie (`No module named ...`), vous pouvez l'installer
# - Soit en utilisant votre gestionnaire d'environnement (p.ex. `conda`).
# - Soit directement depuis le notebook, en faisant
# ```
# !pip install nom_de_la_librairie==numero_de_la_version
# ```
#
# **Attention :** Pour installer tensorflow, vous pouvez _a priori_ faire `pip install tensorflow`, mais en cas de doute, vous pouvez regarder [la doc d'installation](https://www.tensorflow.org/install/pip?hl=fr).
#
# Pour `tensorflow`, assurez-vous de bien avoir la version `2.` (la suite ne devrait pas avoir trop d'importance).
#
# Note : la première fois que vous lancer `import tensorflow as tf`, ça peut prendre assez longtemps (apparemment des choses sont compilées en C en arrière plan).

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import tensorflow as tf

from utils_tp5 import *

print("Version numpy :", np.__version__)
print("Version matplotlib :", matplotlib.__version__)
print("Version tensorflow :", tf.__version__)

# %% [markdown]
# ## Partie 1 : premiers modèles en tensorflow

# %% [markdown]
# Le but de cette partie est de vous faire créer des modèles simples en `tensorflow` et en `pytorch`, les deux librairies de références en _Deep Learning_, et de mettre en place les routines pour entraîner de tels modèles en fonction des deux librairies.

# %% [markdown]
# ### Jeux de données

# %% [markdown]
# On commence par se fabriquer deux jeux de données sur lesquels on testera nos modèles de Deep Learning : un jeu de régression, et un jeu de classification. Les fonctions pour faire ça sont dans un fichier `utils_tp5.py` que vous n'êtes pas obligés d'ouvrir.

# %%
x_reg_train, y_reg_train, x_reg_test, y_reg_test = generate_regression_task()
x_classif_train, y_classif_train, x_classif_test, y_classif_test = generate_classification_task()

# %% [markdown]
# On visualise ça.

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))

ax = axs[0]

ax.scatter(x_reg_train, y_reg_train, marker='x')
ax.set_xlabel("Observations")
ax.set_ylabel("Labels")
ax.set_title("Jeu de régression", fontsize=18)
ax.grid()

ax = axs[1]
ax.scatter(x_classif_train[:,0], x_classif_train[:,1], c=y_classif_train, alpha=0.8)
ax.set_title("Jeu de classification", fontsize=18)
ax.grid()

# %% [markdown]
# ### Régression en tensorflow

# %% [markdown]
# **Question 1: Construction du modèle.** Remplir le code suivant pour créer un modèle `tensorflow` pour le jeu de classification de la manière suivante :
#
# - Le modèle prend les entrées du jeu de régression (1D) et utilise un fully-connected (`Dense`) pour les plonger en dimension 3, avec une activation `relu`
# - Le modèle fait une autre couche qui va de la dimension 3 à a dimension 5, avec une `relu` encore.
# - Le modèle remet ensuite les données en dimension 1 (la dimension des labels), avec une activation `linear` (ce qui revient à prendre $\sigma = \mathrm{id}$).
#
# _Indications:_ On utilisera la syntaxe
# ```
# tf.keras.layers.Dense(units, activation)
# ```
# où `units` et la dimension de _sortie_ du layer, et `activation` est le choix de la fonction d'activation $\sigma$, qui peut valoir `'relu'`, `'sigmoid'` ou `'softmax'` par exemple.
#
# Pour le premier layer, on ajoutera le paramètre `input_shape = (1,)`, pour préciser que l'entrée du modèle sera en 1D (attention, la syntaxe est un peu pénible : `tensorflow` demande un itérable (une liste, un tuple, etc.), donc on est obligé de mettre `(1,)` et pas simplement `1`).

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(3,activation='relu',input_shape=(1,)),   # mettez ici le premier layer
    tf.keras.layers.Dense(5,activation='relu'),   # ici le second layer
    tf.keras.layers.Dense(1,activation ='linear')   # ici le troisième et dernier layer. 
])

# %% [markdown]
# ---

# %% [markdown]
# **Compilation du modèle.** Avant exécution, les modèles tensorflow doivent être "compilés", grâce à la méthode `model.compile(optimizer, loss, metrics)`. On va alors préciser
# - `optimizer` : le choix de l'algorithme d'optimisation. On prendra `'adam'`, un grand classique pour faire une déscente de gradient stochastique
# - `loss` : le choix de la _loss function_. On prendra la _mean squared error_ (mse), qu'on peut fixer en mettant le paramètre `loss` à `'mse'`.
# - `metrics` : la quantité qui nous intéresse. On prendra ici aussi la `'mse'` (voir la partie sur la classification pour comprendre la différence).

# %%
model.compile(
    optimizer='adam', 
    loss='mse', 
    metrics=['mse']
)

# %% [markdown]
# **Question 2: Résumé du modèle.** Après avoir lancé la cellule précédente (compilation du modèle), appeler la méthode `model.summary()` pour répondre aux questions suivantes :
# - Combien votre modèle a-t-il de paramètres ?
# - Sauriez-vous justifier ce nombre par le calcul ?

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 3)                 6
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 20
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 32
# Trainable params: 32
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Le model contient 32 parametres
# dense_8 + dense_9 + dense_10 = Total params<br>
# sachant que :<br>
#  dense_8 = 6<br>
#  dense_9 = 20<br>
#  dense_10 = 6<br>
# On a :<br>
#  6 + 20 + 6 = 32

# %% [markdown]
# **Question 4 : Entraîner le modèle.** En utilisant la méthode `model.fit(x_train, y_train, epochs)`, entraîner le modèle sur votre jeu de régression. On rappelle que `epochs` indique le nombre de parcours _complet_ du jeu de données que vous voulez faire lors de votre Descente de Gradient Stochastique (par batch).
#
# On prendra 5 epochs pour commencer.

# %%
model.fit(x_reg_train,y_reg_train,epochs=5)
# Out:
# Epoch 1/5
# 16/16 [==============================] - 0s 982us/step - loss: 5.9357 - mse: 5.9357
# Epoch 2/5
# 16/16 [==============================] - 0s 1ms/step - loss: 5.8031 - mse: 5.8031
# Epoch 3/5
# 16/16 [==============================] - 0s 997us/step - loss: 5.6957 - mse: 5.6957
# Epoch 4/5
# 16/16 [==============================] - 0s 937us/step - loss: 5.6078 - mse: 5.6078
# Epoch 5/5
# 16/16 [==============================] - 0s 900us/step - loss: 5.5235 - mse: 5.5235

# %% [markdown]
# ---

# %% [markdown]
# **Question 5: Évaluer le modèle.** Tester la performance de votre model avec la méthode `model.evaluate(x_test, y_test)`. On ajoutera comme paramètre à la méthode, `verbose = 2` (qui permet d'avoir directement + de renseignements).
#
# Commentez brièvement les résultats obtenus.

# %%
model.evaluate(x_reg_test,y_reg_test,verbose=2)
# Out:
# 7/7 - 0s - loss: 5.7966 - mse: 5.7966
# [5.796574115753174, 5.796574115753174]

# %% [markdown]
# La loss et la mse est plus faible que lors du ``model.fit()``

# %% [markdown]
# ---

# %% [markdown]
# **Visualiser le modèle.** Comme on est en basse dimension (observations et labels de dimension 1), on peut visualiser "globalement" les prédictions que ferait notre modèle en générant "toutes" les observations possibles en 1D susceptibles de nous intéresser.
#
# Concrètement, on va échantillonner l'intervalle $[0, 4]$ (raisonnable vues nos observations), puis on regarde les prédictions du modèle avec `model.predict(x)`.
#
# **Question 6:** Exécutez le code suivant puis commentez le résultat obtenu.

# %%
t = np.linspace(0, 4, 10000)  # on fabrique "tout" l'intervalle

pred = model.predict(t)

fig, ax = plt.subplots()
ax.plot(t, pred, c='red', label='predictions', linewidth = 3)
ax.scatter(x_reg_train, y_reg_train, marker='x', label='train set', c='blue')
ax.scatter(x_reg_test, y_reg_test, marker='x', label='test set', c='orange')
ax.legend()
ax.grid()

# %% [markdown]
# En lanceant plusieurs fois tout le notebook on remarque que les prédictions du model peuvent varier, cependant plus la losse se rapproche de zéro plus le model suit la courbe.

# %% [markdown]
# ---

# %% [markdown]
# **Question 7:** Relancer l'entraînement du modèle en faisant + d'epochs, et (en faisant un copier-coller) relancez le code de la cellule précédente pour visualiser notre modèle "mieux entraîné".
#
# Commentez le résultat obtenu.
#
# _Remarque:_ Un point assez pratique avec `tensorflow` et qu'on peut simplement "reprendre" l'entraînement en relançant `model.fit(..., epoch=...)`: l'objet `model` est conservé, donc si vous lancez deux fois la cellule `model.fit(..., epoch = 5)`, c'est comme si vous aviez fait 10 epochs. Par contre, si vous relancez `model = ...` (ou si vous redémarrez votre notebook), vous remettez le modèle à 0 bien entendu.
#
# _Remarque 2:_ Il se peut que votre modèle "stagne" près de la fonction nulle. Dans ce cas, relancez-le "depuis 0".

# %%
model.fit(x_reg_train,y_reg_train,epochs=100)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 0s 1ms/step - loss: 5.4336 - mse: 5.4336
# Epoch 2/100
# 16/16 [==============================] - 0s 1ms/step - loss: 5.3365 - mse: 5.3365
# Epoch 3/100
# 16/16 [==============================] - 0s 1ms/step - loss: 5.2306 - mse: 5.2306
# Epoch 4/100
# 16/16 [==============================] - 0s 875us/step - loss: 5.1117 - mse: 5.1117
# Epoch 5/100
# 16/16 [==============================] - 0s 892us/step - loss: 4.9771 - mse: 4.9771
# Epoch 6/100
# 16/16 [==============================] - 0s 923us/step - loss: 4.8218 - mse: 4.8218
# Epoch 7/100
# 16/16 [==============================] - 0s 1ms/step - loss: 4.6420 - mse: 4.6420
# Epoch 8/100
# 16/16 [==============================] - 0s 917us/step - loss: 4.4331 - mse: 4.4331
# Epoch 9/100
# 16/16 [==============================] - 0s 944us/step - loss: 4.1953 - mse: 4.1953
# Epoch 10/100
# 16/16 [==============================] - 0s 922us/step - loss: 3.9331 - mse: 3.9331
# Epoch 11/100
# 16/16 [==============================] - 0s 964us/step - loss: 3.6392 - mse: 3.6392
# Epoch 12/100
# 16/16 [==============================] - 0s 939us/step - loss: 3.3355 - mse: 3.3355
# Epoch 13/100
# 16/16 [==============================] - 0s 960us/step - loss: 3.0224 - mse: 3.0224
# Epoch 14/100
# 16/16 [==============================] - 0s 927us/step - loss: 2.7039 - mse: 2.7039
# Epoch 15/100
# 16/16 [==============================] - 0s 930us/step - loss: 2.3882 - mse: 2.3882
# Epoch 16/100
# 16/16 [==============================] - 0s 973us/step - loss: 2.0889 - mse: 2.0889
# Epoch 17/100
# 16/16 [==============================] - 0s 987us/step - loss: 1.8100 - mse: 1.8100
# Epoch 18/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5533 - mse: 1.5533
# Epoch 19/100
# 16/16 [==============================] - 0s 924us/step - loss: 1.3266 - mse: 1.3266
# Epoch 20/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.1384 - mse: 1.1384
# Epoch 21/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9793 - mse: 0.9793
# Epoch 22/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8561 - mse: 0.8561
# Epoch 23/100
# 16/16 [==============================] - 0s 1000us/step - loss: 0.7631 - mse: 0.7631
# Epoch 24/100
# 16/16 [==============================] - 0s 903us/step - loss: 0.6917 - mse: 0.6917
# Epoch 25/100
# 16/16 [==============================] - 0s 912us/step - loss: 0.6441 - mse: 0.6441
# Epoch 26/100
# 16/16 [==============================] - 0s 987us/step - loss: 0.6113 - mse: 0.6113
# Epoch 27/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5892 - mse: 0.5892
# Epoch 28/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5762 - mse: 0.5762
# Epoch 29/100
# 16/16 [==============================] - 0s 996us/step - loss: 0.5664 - mse: 0.5664
# Epoch 30/100
# 16/16 [==============================] - 0s 999us/step - loss: 0.5612 - mse: 0.5612
# Epoch 31/100
# 16/16 [==============================] - 0s 972us/step - loss: 0.5560 - mse: 0.5560
# Epoch 32/100
# 16/16 [==============================] - 0s 953us/step - loss: 0.5523 - mse: 0.5523
# Epoch 33/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5492 - mse: 0.5492
# Epoch 34/100
# 16/16 [==============================] - 0s 986us/step - loss: 0.5459 - mse: 0.5459
# Epoch 35/100
# 16/16 [==============================] - 0s 968us/step - loss: 0.5433 - mse: 0.5433
# Epoch 36/100
# 16/16 [==============================] - 0s 994us/step - loss: 0.5404 - mse: 0.5404
# Epoch 37/100
# 16/16 [==============================] - 0s 882us/step - loss: 0.5383 - mse: 0.5383
# Epoch 38/100
# 16/16 [==============================] - 0s 997us/step - loss: 0.5350 - mse: 0.5350
# Epoch 39/100
# 16/16 [==============================] - 0s 897us/step - loss: 0.5321 - mse: 0.5321
# Epoch 40/100
# 16/16 [==============================] - 0s 907us/step - loss: 0.5296 - mse: 0.5296
# Epoch 41/100
# 16/16 [==============================] - 0s 942us/step - loss: 0.5270 - mse: 0.5270
# Epoch 42/100
# 16/16 [==============================] - 0s 913us/step - loss: 0.5241 - mse: 0.5241
# Epoch 43/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5217 - mse: 0.5217
# Epoch 44/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5188 - mse: 0.5188
# Epoch 45/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5164 - mse: 0.5164
# Epoch 46/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5138 - mse: 0.5138
# Epoch 47/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5113 - mse: 0.5113
# Epoch 48/100
# 16/16 [==============================] - 0s 923us/step - loss: 0.5090 - mse: 0.5090
# Epoch 49/100
# 16/16 [==============================] - 0s 998us/step - loss: 0.5073 - mse: 0.5073
# Epoch 50/100
# 16/16 [==============================] - 0s 952us/step - loss: 0.5038 - mse: 0.5038
# Epoch 51/100
# 16/16 [==============================] - 0s 900us/step - loss: 0.5014 - mse: 0.5014
# Epoch 52/100
# 16/16 [==============================] - 0s 862us/step - loss: 0.4991 - mse: 0.4991
# Epoch 53/100
# 16/16 [==============================] - 0s 872us/step - loss: 0.4967 - mse: 0.4967
# Epoch 54/100
# 16/16 [==============================] - 0s 861us/step - loss: 0.4945 - mse: 0.4945
# Epoch 55/100
# 16/16 [==============================] - 0s 906us/step - loss: 0.4922 - mse: 0.4922
# Epoch 56/100
# 16/16 [==============================] - 0s 787us/step - loss: 0.4899 - mse: 0.4899
# Epoch 57/100
# 16/16 [==============================] - 0s 804us/step - loss: 0.4877 - mse: 0.4877
# Epoch 58/100
# 16/16 [==============================] - 0s 856us/step - loss: 0.4854 - mse: 0.4854
# Epoch 59/100
# 16/16 [==============================] - 0s 920us/step - loss: 0.4834 - mse: 0.4834
# Epoch 60/100
# 16/16 [==============================] - 0s 947us/step - loss: 0.4811 - mse: 0.4811
# Epoch 61/100
# 16/16 [==============================] - 0s 949us/step - loss: 0.4793 - mse: 0.4793
# Epoch 62/100
# 16/16 [==============================] - 0s 941us/step - loss: 0.4771 - mse: 0.4771
# Epoch 63/100
# 16/16 [==============================] - 0s 871us/step - loss: 0.4751 - mse: 0.4751
# Epoch 64/100
# 16/16 [==============================] - 0s 828us/step - loss: 0.4731 - mse: 0.4731
# Epoch 65/100
# 16/16 [==============================] - 0s 865us/step - loss: 0.4710 - mse: 0.4710
# Epoch 66/100
# 16/16 [==============================] - 0s 832us/step - loss: 0.4693 - mse: 0.4693
# Epoch 67/100
# 16/16 [==============================] - 0s 831us/step - loss: 0.4676 - mse: 0.4676
# Epoch 68/100
# 16/16 [==============================] - 0s 850us/step - loss: 0.4656 - mse: 0.4656
# Epoch 69/100
# 16/16 [==============================] - 0s 771us/step - loss: 0.4638 - mse: 0.4638
# Epoch 70/100
# 16/16 [==============================] - 0s 696us/step - loss: 0.4621 - mse: 0.4621
# Epoch 71/100
# 16/16 [==============================] - 0s 722us/step - loss: 0.4604 - mse: 0.4604
# Epoch 72/100
# 16/16 [==============================] - 0s 777us/step - loss: 0.4586 - mse: 0.4586
# Epoch 73/100
# 16/16 [==============================] - 0s 813us/step - loss: 0.4572 - mse: 0.4572
# Epoch 74/100
# 16/16 [==============================] - 0s 855us/step - loss: 0.4561 - mse: 0.4561
# Epoch 75/100
# 16/16 [==============================] - 0s 863us/step - loss: 0.4546 - mse: 0.4546
# Epoch 76/100
# 16/16 [==============================] - 0s 876us/step - loss: 0.4528 - mse: 0.4528
# Epoch 77/100
# 16/16 [==============================] - 0s 834us/step - loss: 0.4512 - mse: 0.4512
# Epoch 78/100
# 16/16 [==============================] - 0s 903us/step - loss: 0.4499 - mse: 0.4499
# Epoch 79/100
# 16/16 [==============================] - 0s 984us/step - loss: 0.4485 - mse: 0.4485
# Epoch 80/100
# 16/16 [==============================] - 0s 920us/step - loss: 0.4471 - mse: 0.4471
# Epoch 81/100
# 16/16 [==============================] - 0s 842us/step - loss: 0.4459 - mse: 0.4459
# Epoch 82/100
# 16/16 [==============================] - 0s 980us/step - loss: 0.4450 - mse: 0.4450
# Epoch 83/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4435 - mse: 0.4435
# Epoch 84/100
# 16/16 [==============================] - 0s 974us/step - loss: 0.4426 - mse: 0.4426
# Epoch 85/100
# 16/16 [==============================] - 0s 931us/step - loss: 0.4412 - mse: 0.4412
# Epoch 86/100
# 16/16 [==============================] - 0s 982us/step - loss: 0.4401 - mse: 0.4401
# Epoch 87/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4389 - mse: 0.4389
# Epoch 88/100
# 16/16 [==============================] - ETA: 0s - loss: 0.4156 - mse: 0.415 - 0s 941us/step - loss: 0.4380 - mse: 0.4380
# Epoch 89/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4372 - mse: 0.4372
# Epoch 90/100
# 16/16 [==============================] - 0s 975us/step - loss: 0.4363 - mse: 0.4363
# Epoch 91/100
# 16/16 [==============================] - 0s 965us/step - loss: 0.4354 - mse: 0.4354
# Epoch 92/100
# 16/16 [==============================] - 0s 871us/step - loss: 0.4345 - mse: 0.4345
# Epoch 93/100
# 16/16 [==============================] - 0s 796us/step - loss: 0.4338 - mse: 0.4338
# Epoch 94/100
# 16/16 [==============================] - 0s 845us/step - loss: 0.4328 - mse: 0.4328
# Epoch 95/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4322 - mse: 0.4322
# Epoch 96/100
# 16/16 [==============================] - 0s 877us/step - loss: 0.4316 - mse: 0.4316
# Epoch 97/100
# 16/16 [==============================] - 0s 889us/step - loss: 0.4307 - mse: 0.4307
# Epoch 98/100
# 16/16 [==============================] - 0s 864us/step - loss: 0.4299 - mse: 0.4299
# Epoch 99/100
# 16/16 [==============================] - 0s 839us/step - loss: 0.4292 - mse: 0.4292
# Epoch 100/100
# 16/16 [==============================] - 0s 836us/step - loss: 0.4288 - mse: 0.4288

# %%
model.evaluate(x_reg_test,y_reg_test,verbose=2)
# Out:
# 7/7 - 0s - loss: 0.4032 - mse: 0.4032
# [0.4032110273838043, 0.4032110273838043]

# %%
t = np.linspace(0, 4, 10000)  # on fabrique "tout" l'intervalle

pred = model.predict(t)

fig, ax = plt.subplots()
ax.plot(t, pred, c='red', label='predictions', linewidth = 3)
ax.scatter(x_reg_train, y_reg_train, marker='x', label='train set', c='blue')
ax.scatter(x_reg_test, y_reg_test, marker='x', label='test set', c='orange')
ax.legend()
ax.grid()

# %% [markdown]
# Le model deviens plus précis avec plus d'epoch

# %% [markdown]
# ---

# %% [markdown]
# _A priori_, votre modèle est toujours assez mauvais. Ce n'était donc pas une question de nombre d'epochs, mais véritablement d'expressivité du modèle : notre réseau est trop simple.
#
# **Question 8;** Fabriquer un nouveau réseau de neurones (appelez-le par exemple `model2`) similaire au précédent, mais en augmentant son expressivité via :
# - plus de neurones dans les layers intermédiaires
# - plus de layers intermédiaires
# - augmenter le nombre d'epochs si besoin
#
# Reprendre ensuite les questions précédentes, en particulier :
# - Décrire le nombre de paramètres de votre nouveau modèle,
# - Entraîner votre modèle, d'abord pour seulement quelqus epochs, puis + si nécessaire
# - Visualisez votre modèle.
#
# Commentez les résultats que vous obtenez au cours de vos essais.
#
# **Objectif :** avoir une training **et** une test _mse_ $< 0.05$.
#
# **Consigne supplémentaire :** N'hésitez pas à forcer un peu sur les paramètres, **mais** votre réseau doit obligatoirement prendre **moins de 5 minutes pour s'entraîner** (appel de `model.fit`) sur un CPU de laptop ordinaire.

# %%
model2 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(3,activation='relu',input_shape=(1,)),   # mettez ici le premier layer
    tf.keras.layers.Dense(5,activation='relu'),   # ici le second layer
    tf.keras.layers.Dense(2,activation='relu'),
    tf.keras.layers.Dense(4,activation='relu'),
    tf.keras.layers.Dense(20,activation='relu'),
    tf.keras.layers.Dense(114,activation='relu'),
    tf.keras.layers.Dense(1,activation ='linear')   # ici le troisième et dernier layer. 
])

model2.compile(
    optimizer='adam', 
    loss='mse', 
    metrics=['mse']
)

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 3)                 6
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 12
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 12
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                100
# _________________________________________________________________
# dense_8 (Dense)              (None, 114)               2394
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 115
# =================================================================
# Total params: 2,659
# Trainable params: 2,659
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.fit(x_reg_train,y_reg_train,epochs=300)
# Out:
# Epoch 1/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.8483 - mse: 5.8483
# Epoch 2/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.7810 - mse: 5.7810
# Epoch 3/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.7141 - mse: 5.7141
# Epoch 4/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 5.6482 - mse: 5.6482
# Epoch 5/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.5827 - mse: 5.5827
# Epoch 6/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.5183 - mse: 5.5183
# Epoch 7/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.4544 - mse: 5.4544
# Epoch 8/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.3914 - mse: 5.3914
# Epoch 9/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.3288 - mse: 5.3288
# Epoch 10/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.2675 - mse: 5.2675
# Epoch 11/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.2063 - mse: 5.2063
# Epoch 12/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.1465 - mse: 5.1465
# Epoch 13/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.0870 - mse: 5.0870
# Epoch 14/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 5.0277 - mse: 5.0277
# Epoch 15/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.9701 - mse: 4.9701
# Epoch 16/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.9119 - mse: 4.9119
# Epoch 17/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.8556 - mse: 4.8556
# Epoch 18/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.7991 - mse: 4.7991
# Epoch 19/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.7441 - mse: 4.7441
# Epoch 20/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.6893 - mse: 4.6893
# Epoch 21/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.6347 - mse: 4.6347
# Epoch 22/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.5817 - mse: 4.5817
# Epoch 23/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.5286 - mse: 4.5286
# Epoch 24/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.4767 - mse: 4.4767
# Epoch 25/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.4247 - mse: 4.4247
# Epoch 26/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.3737 - mse: 4.3737
# Epoch 27/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.3241 - mse: 4.3241
# Epoch 28/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.2733 - mse: 4.2733
# Epoch 29/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.2249 - mse: 4.2249
# Epoch 30/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.1767 - mse: 4.1767
# Epoch 31/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.1285 - mse: 4.1285
# Epoch 32/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.0814 - mse: 4.0814
# Epoch 33/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 4.0342 - mse: 4.0342
# Epoch 34/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.9884 - mse: 3.9884
# Epoch 35/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.9431 - mse: 3.9431
# Epoch 36/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.8978 - mse: 3.8978
# Epoch 37/1000
# 16/16 [==============================] - ETA: 0s - loss: 4.0618 - mse: 4.061 - 0s 1ms/step - loss: 3.8541 - mse: 3.8541
# Epoch 38/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.8103 - mse: 3.8103
# Epoch 39/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.7671 - mse: 3.7671
# Epoch 40/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.7241 - mse: 3.7241
# Epoch 41/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.6827 - mse: 3.6827
# Epoch 42/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.6402 - mse: 3.6402
# Epoch 43/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.5995 - mse: 3.5995
# Epoch 44/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.5588 - mse: 3.5588
# Epoch 45/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.5195 - mse: 3.5195
# Epoch 46/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.4800 - mse: 3.4800
# Epoch 47/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.4411 - mse: 3.4411
# Epoch 48/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 3.4031 - mse: 3.4031
# Epoch 49/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.3650 - mse: 3.3650
# Epoch 50/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.3277 - mse: 3.3277
# Epoch 51/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.2911 - mse: 3.2911
# Epoch 52/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.2552 - mse: 3.2552
# Epoch 53/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.2189 - mse: 3.2189
# Epoch 54/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.1840 - mse: 3.1840
# Epoch 55/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.1492 - mse: 3.1492
# Epoch 56/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.1147 - mse: 3.1147
# Epoch 57/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.0815 - mse: 3.0815
# Epoch 58/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.0477 - mse: 3.0477
# Epoch 59/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 3.0146 - mse: 3.0146
# Epoch 60/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.9820 - mse: 2.9820
# Epoch 61/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.9500 - mse: 2.9500
# Epoch 62/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.9183 - mse: 2.9183
# Epoch 63/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.8873 - mse: 2.8873
# Epoch 64/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.8566 - mse: 2.8566
# Epoch 65/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.8265 - mse: 2.8265
# Epoch 66/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.7967 - mse: 2.7967
# Epoch 67/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.7675 - mse: 2.7675
# Epoch 68/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.7386 - mse: 2.7386
# Epoch 69/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.7106 - mse: 2.7106
# Epoch 70/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.6826 - mse: 2.6826
# Epoch 71/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.6549 - mse: 2.6549
# Epoch 72/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.6277 - mse: 2.6277
# Epoch 73/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.6013 - mse: 2.6013
# Epoch 74/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.5748 - mse: 2.5748
# Epoch 75/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.5496 - mse: 2.5496
# Epoch 76/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.5234 - mse: 2.5234
# Epoch 77/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.4989 - mse: 2.4989
# Epoch 78/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.4734 - mse: 2.4734
# Epoch 79/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.4496 - mse: 2.4496
# Epoch 80/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.4252 - mse: 2.4252
# Epoch 81/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.4014 - mse: 2.4014
# Epoch 82/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.3787 - mse: 2.3787
# Epoch 83/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.3556 - mse: 2.3556
# Epoch 84/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.3330 - mse: 2.3330
# Epoch 85/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.3113 - mse: 2.3113
# Epoch 86/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.2895 - mse: 2.2895
# Epoch 87/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.2682 - mse: 2.2682
# Epoch 88/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.2471 - mse: 2.2471
# Epoch 89/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.2265 - mse: 2.2265
# Epoch 90/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.2060 - mse: 2.2060
# Epoch 91/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.1863 - mse: 2.1863
# Epoch 92/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.1668 - mse: 2.1668
# Epoch 93/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.1473 - mse: 2.1473
# Epoch 94/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.1284 - mse: 2.1284
# Epoch 95/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.1096 - mse: 2.1096
# Epoch 96/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.0915 - mse: 2.0915
# Epoch 97/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.0736 - mse: 2.0736
# Epoch 98/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.0559 - mse: 2.0559
# Epoch 99/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.0387 - mse: 2.0387
# Epoch 100/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 2.0216 - mse: 2.0216
# Epoch 101/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 2.0049 - mse: 2.0049
# Epoch 102/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.9888 - mse: 1.9888
# Epoch 103/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.9725 - mse: 1.9725
# Epoch 104/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.9565 - mse: 1.9565
# Epoch 105/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.9412 - mse: 1.9412
# Epoch 106/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.9258 - mse: 1.9258
# Epoch 107/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.9110 - mse: 1.9110
# Epoch 108/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.8963 - mse: 1.8963
# Epoch 109/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.8822 - mse: 1.8822
# Epoch 110/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.8679 - mse: 1.8679
# Epoch 111/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.8541 - mse: 1.8541
# Epoch 112/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.8404 - mse: 1.8404
# Epoch 113/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.8274 - mse: 1.8274
# Epoch 114/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.8140 - mse: 1.8140
# Epoch 115/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.8014 - mse: 1.8014
# Epoch 116/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.7887 - mse: 1.7887
# Epoch 117/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.7763 - mse: 1.7763
# Epoch 118/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.7641 - mse: 1.7641
# Epoch 119/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.7525 - mse: 1.7525
# Epoch 120/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.7411 - mse: 1.7411
# Epoch 121/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.7296 - mse: 1.7296
# Epoch 122/1000
# 16/16 [==============================] - ETA: 0s - loss: 1.8843 - mse: 1.884 - 0s 1ms/step - loss: 1.7185 - mse: 1.7185
# Epoch 123/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.7075 - mse: 1.7075
# Epoch 124/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6972 - mse: 1.6972
# Epoch 125/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6865 - mse: 1.6865
# Epoch 126/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6764 - mse: 1.6764
# Epoch 127/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6668 - mse: 1.6668
# Epoch 128/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6569 - mse: 1.6569
# Epoch 129/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6473 - mse: 1.6473
# Epoch 130/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6377 - mse: 1.6377
# Epoch 131/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6290 - mse: 1.6290
# Epoch 132/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6202 - mse: 1.6202
# Epoch 133/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6112 - mse: 1.6112
# Epoch 134/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6030 - mse: 1.6030
# Epoch 135/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5944 - mse: 1.5944
# Epoch 136/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5861 - mse: 1.5861
# Epoch 137/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5787 - mse: 1.5787
# Epoch 138/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5709 - mse: 1.5709
# Epoch 139/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5635 - mse: 1.5635
# Epoch 140/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5560 - mse: 1.5560
# Epoch 141/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5489 - mse: 1.5489
# Epoch 142/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5417 - mse: 1.5417
# Epoch 143/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5351 - mse: 1.5351
# Epoch 144/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5284 - mse: 1.5284
# Epoch 145/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5216 - mse: 1.5216
# Epoch 146/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5157 - mse: 1.5157
# Epoch 147/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5095 - mse: 1.5095
# Epoch 148/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.5036 - mse: 1.5036
# Epoch 149/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4977 - mse: 1.4977
# Epoch 150/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4920 - mse: 1.4920
# Epoch 151/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4866 - mse: 1.4866
# Epoch 152/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4809 - mse: 1.4809
# Epoch 153/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4758 - mse: 1.4758
# Epoch 154/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4706 - mse: 1.4706
# Epoch 155/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4657 - mse: 1.4657
# Epoch 156/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4607 - mse: 1.4607
# Epoch 157/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4560 - mse: 1.4560
# Epoch 158/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4515 - mse: 1.4515
# Epoch 159/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4469 - mse: 1.4469
# Epoch 160/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4426 - mse: 1.4426
# Epoch 161/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4382 - mse: 1.4382
# Epoch 162/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4344 - mse: 1.4344
# Epoch 163/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4303 - mse: 1.4303
# Epoch 164/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4266 - mse: 1.4266
# Epoch 165/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4227 - mse: 1.4227
# Epoch 166/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4192 - mse: 1.4192
# Epoch 167/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4156 - mse: 1.4156
# Epoch 168/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4121 - mse: 1.4121
# Epoch 169/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4087 - mse: 1.4087
# Epoch 170/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4055 - mse: 1.4055
# Epoch 171/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4024 - mse: 1.4024
# Epoch 172/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3993 - mse: 1.3993
# Epoch 173/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3963 - mse: 1.3963
# Epoch 174/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3935 - mse: 1.3935
# Epoch 175/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3910 - mse: 1.3910
# Epoch 176/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3880 - mse: 1.3880
# Epoch 177/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3858 - mse: 1.3858
# Epoch 178/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3831 - mse: 1.3831
# Epoch 179/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3807 - mse: 1.3807
# Epoch 180/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3784 - mse: 1.3784
# Epoch 181/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3761 - mse: 1.3761
# Epoch 182/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3740 - mse: 1.3740
# Epoch 183/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3720 - mse: 1.3720
# Epoch 184/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3700 - mse: 1.3700
# Epoch 185/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3679 - mse: 1.3679
# Epoch 186/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3662 - mse: 1.3662
# Epoch 187/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3643 - mse: 1.3643
# Epoch 188/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3625 - mse: 1.3625
# Epoch 189/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3608 - mse: 1.3608
# Epoch 190/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3591 - mse: 1.3591
# Epoch 191/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3576 - mse: 1.3576
# Epoch 192/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3559 - mse: 1.3559
# Epoch 193/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3546 - mse: 1.3546
# Epoch 194/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3532 - mse: 1.3532
# Epoch 195/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3516 - mse: 1.3516
# Epoch 196/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3504 - mse: 1.3504
# Epoch 197/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3492 - mse: 1.3492
# Epoch 198/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3478 - mse: 1.3478
# Epoch 199/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3468 - mse: 1.3468
# Epoch 200/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3457 - mse: 1.3457
# Epoch 201/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3444 - mse: 1.3444
# Epoch 202/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3435 - mse: 1.3435
# Epoch 203/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3426 - mse: 1.3426
# Epoch 204/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3416 - mse: 1.3416
# Epoch 205/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3406 - mse: 1.3406
# Epoch 206/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3399 - mse: 1.3399
# Epoch 207/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3390 - mse: 1.3390
# Epoch 208/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3381 - mse: 1.3381
# Epoch 209/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3373 - mse: 1.3373
# Epoch 210/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3366 - mse: 1.3366
# Epoch 211/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3358 - mse: 1.3358
# Epoch 212/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3352 - mse: 1.3352
# Epoch 213/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3345 - mse: 1.3345
# Epoch 214/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3339 - mse: 1.3339
# Epoch 215/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3332 - mse: 1.3332
# Epoch 216/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3328 - mse: 1.3328
# Epoch 217/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3321 - mse: 1.3321
# Epoch 218/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3317 - mse: 1.3317
# Epoch 219/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3312 - mse: 1.3312
# Epoch 220/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3307 - mse: 1.3307
# Epoch 221/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3304 - mse: 1.3304
# Epoch 222/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3299 - mse: 1.3299
# Epoch 223/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3295 - mse: 1.3295
# Epoch 224/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3292 - mse: 1.3292
# Epoch 225/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3288 - mse: 1.3288
# Epoch 226/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3285 - mse: 1.3285
# Epoch 227/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3281 - mse: 1.3281
# Epoch 228/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3278 - mse: 1.3278
# Epoch 229/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3275 - mse: 1.3275
# Epoch 230/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3272 - mse: 1.3272
# Epoch 231/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3269 - mse: 1.3269
# Epoch 232/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3266 - mse: 1.3266
# Epoch 233/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3264 - mse: 1.3264
# Epoch 234/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3262 - mse: 1.3262
# Epoch 235/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3259 - mse: 1.3259
# Epoch 236/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3258 - mse: 1.3258
# Epoch 237/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3255 - mse: 1.3255
# Epoch 238/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3254 - mse: 1.3254
# Epoch 239/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3252 - mse: 1.3252
# Epoch 240/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3250 - mse: 1.3250
# Epoch 241/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3249 - mse: 1.3249
# Epoch 242/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3247 - mse: 1.3247
# Epoch 243/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3246 - mse: 1.3246
# Epoch 244/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3245 - mse: 1.3245
# Epoch 245/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3243 - mse: 1.3243
# Epoch 246/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3242 - mse: 1.3242
# Epoch 247/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3241 - mse: 1.3241
# Epoch 248/1000
# 16/16 [==============================] - 0s 935us/step - loss: 1.3240 - mse: 1.3240
# Epoch 249/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3239 - mse: 1.3239
# Epoch 250/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3239 - mse: 1.3239
# Epoch 251/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3237 - mse: 1.3237
# Epoch 252/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3237 - mse: 1.3237
# Epoch 253/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3236 - mse: 1.3236
# Epoch 254/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3235 - mse: 1.3235
# Epoch 255/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3235 - mse: 1.3235
# Epoch 256/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3236 - mse: 1.3236
# Epoch 257/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3234 - mse: 1.3234
# Epoch 258/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3233 - mse: 1.3233
# Epoch 259/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3232 - mse: 1.3232
# Epoch 260/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3232 - mse: 1.3232
# Epoch 261/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3231 - mse: 1.3231
# Epoch 262/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3231 - mse: 1.3231
# Epoch 263/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3230 - mse: 1.3230
# Epoch 264/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3230 - mse: 1.3230
# Epoch 265/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3230 - mse: 1.3230
# Epoch 266/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3229 - mse: 1.3229
# Epoch 267/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3229 - mse: 1.3229
# Epoch 268/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3229 - mse: 1.3229
# Epoch 269/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3228 - mse: 1.3228
# Epoch 270/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3228 - mse: 1.3228
# Epoch 271/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3228 - mse: 1.3228
# Epoch 272/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3228 - mse: 1.3228
# Epoch 273/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3228 - mse: 1.3228
# Epoch 274/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 275/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 276/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 277/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 278/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 279/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 280/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 281/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 282/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 283/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 284/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 285/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 286/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 287/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 288/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 289/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 290/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 291/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 292/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 293/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 294/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 295/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 296/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 297/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 298/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 299/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 300/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 301/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 302/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 303/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 304/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 305/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 306/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 307/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 308/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 309/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 310/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 311/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 312/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 313/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 314/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 315/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 316/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 317/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 318/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 319/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 320/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 321/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 322/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 323/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 324/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 325/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 326/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 327/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 328/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 329/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 330/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 331/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 332/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 333/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 334/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 335/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 336/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 337/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 338/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 339/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 340/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 341/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 342/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 343/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 344/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 345/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3229 - mse: 1.3229
# Epoch 346/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 347/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 348/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 349/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 350/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 351/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 352/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 353/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 354/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 355/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 356/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 357/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 358/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 359/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 360/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 361/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 362/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 363/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 364/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 365/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 366/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 367/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 368/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 369/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 370/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 371/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 372/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 373/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 374/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 375/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 376/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 377/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 378/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 379/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 380/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 381/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 382/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 383/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 384/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 385/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 386/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 387/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 388/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 389/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 390/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 391/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 392/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 393/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 394/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 395/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 396/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 397/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 398/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 399/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 400/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 401/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 402/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 403/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 404/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 405/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 406/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 407/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 408/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 409/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 410/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 411/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 412/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 413/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 414/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 415/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 416/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 417/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 418/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 419/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 420/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 421/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 422/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 423/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 424/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 425/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 426/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 427/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 428/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 429/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 430/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 431/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 432/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 433/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 434/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 435/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 436/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 437/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 438/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 439/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 440/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 441/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 442/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 443/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 444/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 445/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 446/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 447/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 448/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 449/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 450/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 451/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 452/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 453/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 454/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 455/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 456/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 457/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 458/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 459/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 460/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 461/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 462/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 463/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 464/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 465/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 466/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 467/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 468/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 469/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 470/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 471/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 472/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 473/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 474/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 475/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 476/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 477/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 478/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 479/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 480/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 481/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 482/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 483/1000
# 16/16 [==============================] - ETA: 0s - loss: 1.5002 - mse: 1.500 - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 484/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 485/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 486/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 487/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 488/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 489/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 490/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 491/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 492/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 493/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 494/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 495/1000
# ...
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 837/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 838/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 839/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 840/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 841/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 842/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 843/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 844/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 845/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 846/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 847/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3228 - mse: 1.3228
# Epoch 848/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 849/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 850/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 851/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 852/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 853/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 854/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 855/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 856/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 857/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 858/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 859/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 860/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 861/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 862/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 863/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 864/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 865/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 866/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 867/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 868/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 869/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 870/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 871/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 872/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 873/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 874/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 875/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 876/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 877/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 878/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 879/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 880/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 881/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 882/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 883/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 884/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 885/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 886/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 887/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 888/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 889/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 890/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 891/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 892/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 893/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 894/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 895/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 896/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 897/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 898/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 899/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 900/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 901/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 902/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 903/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 904/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 905/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 906/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 907/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 908/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 909/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 910/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 911/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 912/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 913/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 914/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 915/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 916/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 917/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 918/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 919/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 920/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 921/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 922/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 923/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 924/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 925/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 926/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 927/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 928/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 929/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 930/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 931/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 932/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 933/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 934/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 935/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 936/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 937/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 938/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 939/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 940/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 941/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 942/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 943/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 944/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 945/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 946/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 947/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 948/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 949/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 950/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 951/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 952/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 953/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 954/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 955/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 956/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 957/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 958/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 959/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 960/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 961/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 962/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 963/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 964/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 965/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 966/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 967/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 968/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 969/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 970/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 971/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 972/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3227 - mse: 1.3227
# Epoch 973/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 974/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 975/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 976/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 977/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 978/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 979/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 980/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 981/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 982/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 983/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 984/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 985/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 986/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 987/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 988/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 989/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 990/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 991/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 992/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 993/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 994/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 995/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 996/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 997/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 998/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3226 - mse: 1.3226
# Epoch 999/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225
# Epoch 1000/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3225 - mse: 1.3225

# %%
model2.evaluate(x_reg_test, y_reg_test)
# Out:
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3592 - mse: 1.3592
# [1.3592208623886108, 1.3592208623886108]

# %%
t = np.linspace(0, 4, 10000)  # on fabrique "tout" l'intervalle

pred = model2.predict(t)

fig, ax = plt.subplots()
ax.plot(t, pred, c='red', label='predictions', linewidth = 3)
ax.scatter(x_reg_train, y_reg_train, marker='x', label='train set', c='blue')
ax.scatter(x_reg_test, y_reg_test, marker='x', label='test set', c='orange')
ax.legend()
ax.grid()

# %% [markdown]
# ---

# %% [markdown]
# ### Classification en tensorflow

# %% [markdown]
# On passe maintenant à la classification. Le principe reste le même que pour la régression, avec trois différences :
# - En classification, on utilise comme `loss` (la fonction qu'on veut minimiser) l'entropie croisée, mais comme `metrics` (la valeur qu'on interprête / qu'on veut communiquer) l'`accuracy` (proportion de prédictions correctes). On utilisera ici `loss = tf.keras.losses.SparseCategoricalCrossEntropy()`
# - Pour pouvoir utiliser l'entropie croisée, il faut en théorie utiliser le _one-hot_encoding_ des labels. En réalité, `tensorflow` gère cela automatiquement avec la  `SparseCategoricalCrossEntropy()`.
# - Lorsqu'on appelle `model.predict(x)`, on récupère _une distribution de probabilité sur l'ensemble des classes_ (donc un vecteur de taille `nombre_de_classes`). Pour récuperer une "vraie" prédiction, il faut faire `np.argmax(model.predict(x), axis=1)` (qui permet de sélectionner la classe qui a la plus haute probabilité estimée par le modèle).

# %% [markdown]
# **Question 1:** Initialiser un réseau de neurone avec seulement deux layers :
# - Le premier envoie les observations en dimension 10, avec une activation `sigmoid`
# - Le deuxième envoie les observation en dimension 3, avec une activation `softmax`.

# %%
model3 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10,activation='sigmoid',input_shape=(2,)),   # mettez ici le premier layer
    tf.keras.layers.Dense(3,activation='softmax'),   # ici le second layer
])

# %% [markdown]
# ---

# %% [markdown]
# **Question 2:** Pourquoi a-t-on pris une dimension de 3 pour la sortie du deuxième (et dernier) layer ? Pourquoi a-t-on pris l'activation `softmax` ?

# %% [markdown]
# Nous cherchons 3 probabilités représentants les 3 couleurs vu précédement

# %% [markdown]
# ---

# %% [markdown]
# **Question 3:** Compilez votre modèle. On prendra toujours `'adam'` comme `optimizer`, mais on prendra comme indiqué la `SparseCategoricalCrossEntropy()` comme `loss`, et `['accuracy']` comme `metrics`.

# %%
model3.compile(
    optimizer='adam', 
    loss='SparseCategoricalCrossentropy', 
    metrics=['accuracy']
)

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 63
# Trainable params: 63
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ---

# %% [markdown]
# **Question 4:** Entraînez votre modèle sur 5 epochs, évaluez son score (sur le jeu de test), et commentez vos résultats. On fournit notamment une cellule de code pour visualiser l'ensemble des prédictions sur une grille $[-15, 15]\times[-5,5]$ de votre modèle après entraînement.

# %%
model3.fit(x_classif_train, y_classif_train,epochs=5)
# Out:
# Epoch 1/5
# 32/32 [==============================] - 0s 695us/step - loss: 1.0431 - accuracy: 0.4620
# Epoch 2/5
# 32/32 [==============================] - 0s 658us/step - loss: 0.9964 - accuracy: 0.5790
# Epoch 3/5
# 32/32 [==============================] - 0s 765us/step - loss: 0.9554 - accuracy: 0.6400
# Epoch 4/5
# 32/32 [==============================] - 0s 815us/step - loss: 0.9163 - accuracy: 0.6550
# Epoch 5/5
# 32/32 [==============================] - 0s 824us/step - loss: 0.8789 - accuracy: 0.6590

# %%
model3.evaluate(x_classif_test, y_classif_test)
# Out:
# 32/32 [==============================] - 0s 706us/step - loss: 0.8586 - accuracy: 0.6570
# [0.8586252331733704, 0.6570000052452087]

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-15, 15, 100)
grid = np.array(np.meshgrid(x,y)).reshape(2, 10000).T  # On fabrique une grille sur laquelle on va tester notre modèle
pred_proba = model3.predict(grid)  # on évalue notre modèle sur la grille --> donne des probabilité d'appartenance
predictions = np.argmax(pred_proba, axis=-1)  # On récupère nos prédictions sous forme de classes

fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(grid[:,0], grid[:,1], c=predictions, alpha = 0.1)
ax.scatter(x_classif_train[:,0], x_classif_train[:,1], c=y_classif_train, marker='o', edgecolor='k', label="train set")
ax.set_title("Prédictions du modèle (ombre) vs données d'entraînement")
# Out:
# Text(0.5, 1.0, "Prédictions du modèle (ombre) vs données d'entraînement")

# %% [markdown]
# ---

# %% [markdown]
# **Question 5:** Essayer d'améliorer votre score (train et test !) avec un modèle plus raffiné. Attention à l'_overfiting_!
#
# Objectif : accuracy $> 94\%$ sur train et test.

# %%
# Écrivez votre code ici

# %% [markdown]
# ---

# %% [markdown]
# ## Partie 2 : Le jeu CIFAR10 et les réseaux convolutionnels

# %% [markdown]
# On va maintenant tester de nouvelles architectures sur un classique des jeux de données : le jeu `CIFAR10`. C'est un jeu de données représentant des images (attention il est un peu volumineux, essayez d'avoir un peu de place sur votre machine avant de lancer la cellule de code suivant qui le téléchargera).
#
# Les images ont $32 \times 32$ pixels et troix canaux de couleur (Rouge, Bleu, Vert) qui prennent des valuers entre $0$ et $255$, et qu'on va normaliser à $[0,1]$ pour simplifier.
#
# Ces images sont réparties dans 10 classes, dont les noms sont stockés dans la liste `noms_classes` ci-dessous :

# %%
noms_classes = ['avion', 'voiture', 'oiseau', 'chat', 'cerf',
               'chien', 'grenouille', 'cheval', 'bateau', 'camion']

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#  68476928/170498071 [===========>..................] - ETA: 39s

# %%
num = 0  # vous pouvez essayer d'autres num
image = x_train[num]
label = y_train[num]
plt.imshow(image, cmap='Greys')
plt.title('Image de %s' %noms_classes[label[0]], fontsize=24)

# %% [markdown]
# **Question 1:** En quelle dimension sont nos données ?

# %% [markdown]
# -- Écrivez votre réponse ici --

# %% [markdown]
# ---

# %% [markdown]
# **Question 2:** En reprenant le code de la Partie précédente, instanciez, entraînez puis évaluez un modèle fully-connected sur ce jeu de données.
#
# **Important :** Le premier layer sera `tf.keras.layers.flatten()`, qui permet simplement de passer d'une image $32 \times 32 \times 3$ à un vecteur "ligne" (le type d'entrée que demande `tensorflow`). Le dernier avec une sortie de taille 10 (nombre de classes).
#
# Ne vous acharnez pas trop : avec un jeu de données difficile comme celui-ci, on se fixe dans un premier temps un objectif de $> 35\%$ de train **et** test accuracy.
#
#
# _Remarque :_ Comme le jeu de donnée est nettement plus gros, on peut généralement faire moins d'epochs (car 1 epoch ==> plus d'étapes de SGD à batch size fixée). Par contre les epochs seront plus longues. Commencez par en faire un petit nombre ($< 5$) pour voir ce que ça donne sur votre machine.
#
# _Remarque 2:_ Attention à l'overfiting ! En grande dimension, c'est très facile d'_overfit_.

# %%
# Écrivez votre code ici

# %% [markdown]
# ---

# %% [markdown]
# **Question 3:** Combien votre modèle a-t-il de paramètres ?

# %%
# Écrivez votre code ici

# %% [markdown]
# ---

# %% [markdown]
# L'espace des _images naturelles_ (les "vraies" images qu'on est susceptible de voir dans la vie de tous les jours) est trop compliqué pour être appris avec un réseau de neurones aussi élémentaire, qui traite chaque pixel (et chaque canal de couleur !) de manière totalement indépendante. On va donc se reposer sur un [layer _convolutionnel_](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D).
#
# On y accède via :
#
# ```
# tf.keras.layers.Conv2D(filters, kernel_size, activation, input_shape)
# ```
#
# où `filters` représente le nombre de filtres (nombre de matrices $A$ vu en cours) qu'on veut apprendre en parallèle, `kernel_size` représente la taille de ces filtres, `activation` est la fonction d'activation (mêmes choix que précédemment), et `input_shape` (utile pour le premier layer uniquement) permet de spécifier la taille des images (nombre de pixel x nombre de pixel x nombre de canaux).
#
# On utilisera aussi le layer `tf.keras.layers.MaxPooling2D((n,n))` qui découpe l'image en patch de taille `n x n` (où `n` est un paramètre que vous choisissez)

# %% [markdown]
# ---

# %% [markdown]
# **Question 4:** Instancier un réseau avec les layers suivants :
# - Le premier est un layer convolutionnel avec 16 filtres de taille `(3,3)`, une activation `'relu'`, et on précisera l'`input_shape`.
# - Le second est un `MaxPooling2D` avec `n=2`.
# - Le troisième est un layer convolutionnel avec 32 filtres de taille `(3,3)` et une activation `'relu'`.
# - Le quatrième est un layer `Flatten()` pour récupérer des vecteurs ligne.
# - Le dernier est un layer `Dense` avec une sortie de taille 10, et une activation `'softmax'`.

# %%
# Écrivez votre code ici

# %% [markdown]
# ---

# %% [markdown]
# **Quesiton 5:** Compiler ce modèle, puis indiquer son nombre de paramètres.

# %%
# Écrivez votre code ici

# %% [markdown]
# ---

# %% [markdown]
# **Question 6:** Entraînez et évaluez ce modèle sur le jeu de données `CIFAR10` en faisant 5 epochs. À quelle train et test accuracy arrivez-vous ?

# %%
# Écrivez votre code ici.

# %% [markdown]
# ---

# %% [markdown]
# **Question 7: (facultatif)** Améliorez ce modèle. Quelques points de repère :
# - Au dessus de $70\%$ : correct.
# - Au dessus de $80\%$ : vraiment bien
# - Au dessus de $85\%$ : très très bien
# - Au dessus de $90\%$ : excellent, c'est plutôt un score qu'on atteint avec des méthodes plus sophistiquées d'habitude (comme les [ResNet](https://en.wikipedia.org/wiki/Residual_neural_network)).
# - Au dessus de $95\%$ : Hallucinant, ce sont des scores de modèles très récents de haut vol.
# - Au dessus de $99,2\%$ : nouveau record du monde !
# - $100\%$ : Très douteux, sachant que [certains labels sont **faux**](https://franky07724-57962.medium.com/once-upon-a-time-in-cifar-10-c26bb056b4ce) (0.3% semble-t-il).

# %%
# Écrivez votre code ici
